# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize']=(20,10)

# %%
data = pd.read_csv('datasets/DEOK_hourly.csv')
data['Datetime']=pd.to_datetime(data['Datetime'])
data.set_index('Datetime', inplace=True)
n = data.shape[0]
y= data['DEOK_MW']

data.plot()
data.plot.density()

# %% [markdown]
# The Data looks stationary from the data plot and density plot.
#
# We apply statistical Tests to check

# %% [markdown]
# 1. Augmented Dickey-Fuller Test -
#
#     Null-Hypothesis : Unit Root is present (Non Stationary)

# %%
from statsmodels.tsa.stattools import adfuller

dftest = adfuller(y, autolag='AIC')

print ('Results of Dickey-Fuller Test:\n')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
   dfoutput['Critical Value (%s)'%key] = value
print (dfoutput)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                -1.491327e+01
# p-value                        1.447767e-27
# #Lags Used                     5.700000e+01
# Number of Observations Used    5.768100e+04
# Critical Value (1%)           -3.430463e+00
# Critical Value (5%)           -2.861590e+00
# Critical Value (10%)          -2.566797e+00
# dtype: float64

# %% [markdown]
# As p-value<0.05, we reject the NULL hypothesis. So the data is stationary.

# %% [markdown]
# 2. KPSS (Kwiatkowski-Phillips-Schmidt-Shin) Test -
#
#     Null Hypothesis: The process is trend stationary.
#
#     Alternate Hypothesis: The series has a unit root

# %%
from statsmodels.tsa.stattools import kpss

def kpss_test(timeseries):
    print ('Results of KPSS Test:\n')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
        kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)
    
kpss_test(y)
# Out:
# Results of KPSS Test:
#
# Test Statistic            0.395427
# p-value                   0.079126
# Lags Used                59.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %% [markdown]
# As p-value>0.05, NULL Hypothesis is not rejected
